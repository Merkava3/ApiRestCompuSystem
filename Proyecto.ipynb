# %% [markdown]
# <a href="https://colab.research.google.com/github/Merkava3/ApiRestCompuSystem/blob/main/Proyecto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

try:
    # Leer el archivo CSV con el delimitador adecuado
    df_resultados_2020_2 = pd.read_csv('/content/drive/MyDrive/Datos/Dataset_Actualizado_rafa.csv', delimiter=';')

    # Si la lectura del archivo es exitosa, imprime un mensaje indicando que el dataset se cargó correctamente
    print("El dataset se cargó exitosamente.")
    #print(df_resultados_2020_2.sample(10))

except FileNotFoundError as e:
    print(f"Error: El archivo no se pudo encontrar. Detalles: {e}")

except Exception as e:
    print(f"Error inesperado: {e}")

df_resultados_2020_2
# Out:
# El dataset se cargó exitosamente.
#       Edad Sexo Estrato    Zona Estado_civil           centro  \
# 0       40    M     Uno  Urbana     Casado/a  Puerto Colombia
# 1       19    F     Dos  Urbana    Soltero/a       Valledupar
# 2       18    M    Tres  Urbana    Soltero/a          Corozal
# 3       24    F     Uno  Urbana  Union Libre         Sahagún
# 4       30    F     Uno  Urbana     Casado/a         Sahagún
# ...    ...  ...     ...     ...          ...              ...
# 2251    22    M     Uno   Rural    Soltero/a       La Guajira
# 2252    15    F     Uno   Rural    Soltero/a       Valledupar
# 2253    39    F     Uno  Urbana    Soltero/a       La Guajira
# 2254    26    F     Dos  Urbana    Soltero/a  Puerto Colombia
# 2255    32    M     Dos  Urbana  Union Libre        Cartagena
#
#                                                 Escuela  \
# 0           ECEDU - Escuela de Ciencias de la Educación
# 1               ECISA - Escuela de Ciencias de la Salud
# ...
